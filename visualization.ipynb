# %% [markdown]
# ## Observe state as image
#
# Use `save_state_as_image` function to store state and action as image.
#
# For example:
#
# <img src="assets/ep_0_t_112_action_2_crashed_False.jpg" caption="test" align="center" width="400">
#
# `ep_0_t_112_action_2_crashed_False.jpg`
#
# <img src="assets/ep_0_t_113_action_2_crashed_True.jpg" align="center" width="400">
#
# `ep_0_t_113_action_2_crashed_True.jpg`

# %% [markdown]
# ## Training history
#
# The following chart shows the average steps in 10 games, from 9 to 9999 episodes, in training process.

# %%
from utils import plot_train_history
plot_train_history()
